# %% [markdown]
# # Свойства элетродов

# %% [markdown]
# Цели работы:
# 1. Исследование базовых свойств электродов, способности поляризоваться (изменять заряд) под действием внешнего напряжения
# 2. Знакомство с факторами, определяющими свойство поляризуемости
# 4. Знакомство с принципом работы трехэлектродной схемы, требованиям к электродам и их расположению
# 5. Знакомство с понятием лимитирующей стадии электрохимической реакции и двумя принципиально разными причинами изменения потенциала электрода в условиях протекания тока – при быстрой и медленной электрохимической стадии
# 6. Особые требования к элементам трехэлектродной схемы при исследовании вольт-амперных характеристик протекающих реакций
# 7. Получение хлорсеребряного электрода и изучение его свойств.
# 8. Исследование свойств платинового электрода в условиях его поляризуемости и обратимости. Оценка ключевых параметров диффузионной и кинетической стадий электрохимических реакций.

# %% [markdown]
# ### 1. Получение и проверка работы хлорсеребряных электродов

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
frame = pd.read_csv('1222.csv', sep=',')

# %%
x = frame['U, mV']
x = x[:]
y = frame['I, mkA']
y = y[:]
plt.plot(x, y, 'o', markersize=1, color = 'lightcoral')
plt.xlabel('U, mV')
plt.ylabel('I, mkA')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
frame_pt = pd.read_csv('1222(circle-pt).csv', sep=',')
frame_ag = pd.read_csv('1222(circle-ag).csv', sep=',')

# %%
x = frame_pt['U, mV']
x = x[:]
y = frame_pt['I, mkA']
y = y[:]
plt.plot(x, y, 'o', markersize=1, color = 'lightcoral')
plt.xlabel('U, mV')
plt.ylabel('I, mkA')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = frame_ag['U, mV']
x = x[:]
y = frame_ag['I, mkA']
y = y[:]
plt.plot(x, y, 'o', markersize=1, color = 'lightcoral')
plt.xlabel('U, mV')
plt.ylabel('I, mkA')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
